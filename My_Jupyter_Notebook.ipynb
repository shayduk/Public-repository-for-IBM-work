# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Steven Hayduk__
#
# Professor of Psychology

# %% [markdown]
# _I'm interested in data science as an extension of my interest in statistics and my interest in visual attention (e.g., machine learning and computer vision)_

# %% [markdown]
# ### The code below creates a 2D matrix of integers and adds a scalar value (i.e., 2) to the matrix.

# %%
import numpy as np

a = [[1, 2, 3, 4, 5],[1, 0, 1, 0, 1],[5, 4, 3, 2, 1]]
print(a)
b = np.add(a, 2)
print(b)
# Out:
# [[1, 2, 3, 4, 5], [1, 0, 1, 0, 1], [5, 4, 3, 2, 1]]
# [[3 4 5 6 7]
#  [3 2 3 2 3]
#  [7 6 5 4 3]]

# %% [markdown]
# #### General comments
#
# Have you tried the new ChatGPT chatbot? You can create an account to try it at: https://openai.com/blog/chatgpt/
#
# ***
#
# We have 3 indoor cats and 2 outdoor cats. The last two cats are our outdoor cats.
# 1. Victor - a tuxedo or bicolor cat
# 1. Alex - a tuxedo cat
# 1. Milo - a ginger cat
#
# 1. Ginger - a ginger cat
# 1. Waldo - a tuxedo cat, part Maine Coon
#
# ***
# A picture of our backyard garden.
#
# ![Timothy's garden.jpg](attachment:aee42850-1e7d-4c52-82bf-c3a13aa1d607.jpg)
